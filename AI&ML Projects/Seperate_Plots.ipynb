# %%
import pandas as pd
from statsmodels.tsa.seasonal import STL
import matplotlib.pyplot as plt
from datetime import datetime

# %%
csv_data = pd.read_csv("C:/Users/MUHAMMED SHAH/Desktop/Observability server data/SET 2/SERVER 1/new_csv_formatted.csv")
data = csv_data.copy()

# %%
data.timestamp = pd.to_datetime(data.timestamp)
data.set_index("timestamp", inplace=True)

# %%
plt.figure(figsize=(70000,50000))
data.plot()
plt.show()

# %%
plt.figure(figsize=(20,8))
data["vmMemoryDemand"].plot()
plt.show()

# %%
plt.figure(figsize=(20,8))
data["guest_demand"].plot()
plt.show()

# %%
plt.figure(figsize=(20,8))
data["guest_provisioned"].plot()
plt.show()

# %%
plt.figure(figsize=(20,8))
data["vm_capacity_provisioned"].plot()
plt.show()

# %%
plt.figure(figsize=(20,8))
data["effective_limit"].plot()
plt.show()
